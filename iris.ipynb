# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv('iris.csv')
import site
print(site.getsitepackages())
print(site.getusersitepackages())
import sys
# Out:
# ['c:\\Users\\USER\\AppData\\Local\\Programs\\Python\\Python313', 'c:\\Users\\USER\\AppData\\Local\\Programs\\Python\\Python313\\Lib\\site-packages']
# C:\Users\USER\AppData\Roaming\Python\Python313\site-packages

# %%
df.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
plt.hist(df['Sepal.Length'], bins=20, color='blue', alpha=0.7)
plt.title('Histogram of Sepal Length')
plt.xlabel('Sepal Length (cm)')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
df.boxplot(column='Sepal.Length', by='Species', grid=False)
plt.title('Boxplot of Sepal Length by Species')
# Out:
# Text(0.5, 1.0, 'Boxplot of Sepal Length by Species')

# %%
df['Sepal.Length'].plot(kind='box', grid=False, title='Boxplot of Sepal Length')
# Out:
# <Axes: title={'center': 'Boxplot of Sepal Length'}>

# %%
sns.boxplot(x='Species', y='Sepal.Length', data=df, palette='Set3')
plt.title('Boxplot of Sepal Length by Species')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_20196\3071619476.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y='Sepal.Length', data=df, palette='Set3')
# Text(0.5, 1.0, 'Boxplot of Sepal Length by Species')
